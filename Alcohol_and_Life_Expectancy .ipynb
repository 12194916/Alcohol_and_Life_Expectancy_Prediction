# %%
import pandas as pd #importing pandas libary
import numpy as np #importing numpy libary

# %%
df_1=pd.read_csv("/content/drinks.csv") #reading first dataset
df_1
# Out:
#      index      country  beer_servings  spirit_servings  wine_servings  \
# 0        0  Afghanistan              0                0              0
# 1        1      Albania             89              132             54
# 2        2      Algeria             25                0             14
# 3        3      Andorra            245              138            312
# 4        4       Angola            217               57             45
# ..     ...          ...            ...              ...            ...
# 188    188    Venezuela            333              100              3
# 189    189      Vietnam            111                2              1
# 190    190        Yemen              6                0              0
# 191    191       Zambia             32               19              4
# 192    192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 6 columns]

# %%
df_2=pd.read_csv("/content/lifeexpectancy-verbose.csv") #reading second dataset
df_2
# Out:
#       index        GhoCode                                       GhoDisplay  \
# 0         0  WHOSIS_000001                 Life expectancy at birth (years)
# 1         1  WHOSIS_000002  Healthy life expectancy (HALE) at birth (years)
# 2         2  WHOSIS_000001                 Life expectancy at birth (years)
# 3         3  WHOSIS_000001                 Life expectancy at birth (years)
# 4         4  WHOSIS_000015                Life expectancy at age 60 (years)
# ...     ...            ...                                              ...
# 6403   6403  WHOSIS_000001                 Life expectancy at birth (years)
# 6404   6404  WHOSIS_000015                Life expectancy at age 60 (years)
# 6405   6405  WHOSIS_000001                 Life expectancy at birth (years)
# 6406   6406  WHOSIS_000002  Healthy life expectancy (HALE) at birth (years)
# 6407   6407  WHOSIS_000001                 Life expectancy at birth (years)
#
#      PublishStateCode PublishStateDisplay  YearCode  YearDisplay RegionCode  \
# 0           PUBLISHED           Published      1990         1990        AMR
# 1           PUBLISHED           Published      2012         2012        EUR
# 2           PUBLISHED           Published      2000         2000        EMR
# 3           PUBLISHED           Published      2000         2000        AFR
# 4           PUBLISHED           Published      1990         1990       SEAR
# ...               ...                 ...       ...          ...        ...
# 6403        PUBLISHED           Published      2000         2000        EMR
# 6404        PUBLISHED           Published      1990         1990        WPR
# 6405        PUBLISHED           Published      1990         1990        AFR
# 6406        PUBLISHED           Published      2012         2012        EUR
# 6407        PUBLISHED           Published      2013         2013        EUR
#
#               RegionDisplay WorldBankIncomeGroupGroupCode  \
# 0                  Americas                        WB_LMI
# 1                    Europe                         WB_HI
# 2     Eastern Mediterranean                         WB_LI
# 3                    Africa                        WB_LMI
# 4           South_East Asia                        WB_LMI
# ...                     ...                           ...
# 6403  Eastern Mediterranean                        WB_LMI
# 6404        Western Pacific                        WB_UMI
# 6405                 Africa                         WB_LI
# 6406                 Europe                        WB_LMI
# 6407                 Europe                           NaN
#
#      WorldBankIncomeGroupDisplay CountryCode CountryDisplay SexCode  \
# 0            Lower_middle_income         NIC      Nicaragua     MLE
# 1                    High_income         IRL        Ireland     MLE
# 2                     Low_income         YEM          Yemen    BTSX
# 3            Lower_middle_income         NGA        Nigeria    FMLE
# 4            Lower_middle_income         THA       Thailand    FMLE
# ...                          ...         ...            ...     ...
# 6403         Lower_middle_income         MAR        Morocco    BTSX
# 6404         Upper_middle_income         PLW          Palau    BTSX
# 6405                  Low_income         BFA   Burkina Faso    FMLE
# 6406         Lower_middle_income         ALB        Albania     MLE
# 6407                         NaN         ARM        Armenia    BTSX
#
#       SexDisplay  DisplayValue   Numeric
# 0           Male            68  68.00000
# 1           Male            69  69.30000
# 2     Both sexes            61  61.00000
# 3         Female            48  48.00000
# 4         Female            19  19.00000
# ...          ...           ...       ...
# 6403  Both sexes            68  68.00000
# 6404  Both sexes            16  16.00000
# 6405      Female            51  51.00000
# 6406        Male            64  63.50000
# 6407  Both sexes            71  71.02699
#
# [6408 rows x 17 columns]

# %%
df_1=df_1.drop('index',axis=1) #dropping the index column as they are duplicated
df_2=df_2.drop('index',axis=1)

# %%
df_2['GhoDisplay'].unique() # checking the column values.
# Out:
# array(['Life expectancy at birth (years)',
#        'Healthy life expectancy (HALE) at birth (years)',
#        'Life expectancy at age 60 (years)'], dtype=object)

# %%
df_1.isnull().sum() #checking the  null values of dataset
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# dtype: int64

# %%
df_2.isnull().sum() #checking the  null values of dataset
# Out:
# GhoCode                             0
# GhoDisplay                          0
# PublishStateCode                    0
# PublishStateDisplay                 0
# YearCode                            0
# YearDisplay                         0
# RegionCode                          0
# RegionDisplay                       0
# WorldBankIncomeGroupGroupCode    1164
# WorldBankIncomeGroupDisplay      1164
# CountryCode                         0
# CountryDisplay                      0
# SexCode                             0
# SexDisplay                          0
# DisplayValue                        0
# Numeric                             0
# dtype: int64

# %% [markdown]
# I am going to fill in the nan values with the most frequent values. So I am using "Counter" libary.

# %%
from collections import Counter
first_nan_column=df_2['WorldBankIncomeGroupGroupCode']
counter_1 = Counter(first_nan_column)
most_common_1 = counter_1.most_common(1)

second_nan_column=df_2['WorldBankIncomeGroupDisplay']
counter_2 = Counter(second_nan_column)
most_common_2 = counter_2.most_common(1)
most_common_1,most_common_2
# Out:
# ([('WB_LMI', 1440)], [('Lower_middle_income', 1440)])

# %%
df_2['WorldBankIncomeGroupGroupCode']=df_2['WorldBankIncomeGroupGroupCode'].fillna(most_common_1[0][0])
df_2['WorldBankIncomeGroupDisplay']=df_2['WorldBankIncomeGroupDisplay'].fillna(most_common_1[0][0])
df_2.isnull().sum()  #using the above code for certain columns with nan values.
# Out:
# GhoCode                          0
# GhoDisplay                       0
# PublishStateCode                 0
# PublishStateDisplay              0
# YearCode                         0
# YearDisplay                      0
# RegionCode                       0
# RegionDisplay                    0
# WorldBankIncomeGroupGroupCode    0
# WorldBankIncomeGroupDisplay      0
# CountryCode                      0
# CountryDisplay                   0
# SexCode                          0
# SexDisplay                       0
# DisplayValue                     0
# Numeric                          0
# dtype: int64

# %%
len(df_2['CountryDisplay'].unique()),len(df_1['country'].unique())  #i can easly concat them, because the number of countrues are almost the same in both datasets
# Out:
# (194, 193)

# %%
df_2=df_2.rename(columns={'CountryDisplay':'country'}) #renaming the column to concat the datasets

# %%
df = pd.merge(df_1, df_2, on='country') #merging the datasets with "country" column

# %%
df
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 0     Afghanistan              0                0              0
# 1     Afghanistan              0                0              0
# 2     Afghanistan              0                0              0
# 3     Afghanistan              0                0              0
# 4     Afghanistan              0                0              0
# ...           ...            ...              ...            ...
# 5506     Zimbabwe             64               18              4
# 5507     Zimbabwe             64               18              4
# 5508     Zimbabwe             64               18              4
# 5509     Zimbabwe             64               18              4
# 5510     Zimbabwe             64               18              4
#
#       total_litres_of_pure_alcohol        GhoCode  \
# 0                              0.0  WHOSIS_000015
# 1                              0.0  WHOSIS_000001
# 2                              0.0  WHOSIS_000002
# 3                              0.0  WHOSIS_000015
# 4                              0.0  WHOSIS_000015
# ...                            ...            ...
# 5506                           4.7  WHOSIS_000002
# 5507                           4.7  WHOSIS_000001
# 5508                           4.7  WHOSIS_000002
# 5509                           4.7  WHOSIS_000001
# 5510                           4.7  WHOSIS_000001
#
#                                            GhoDisplay PublishStateCode  \
# 0                   Life expectancy at age 60 (years)        PUBLISHED
# 1                    Life expectancy at birth (years)        PUBLISHED
# 2     Healthy life expectancy (HALE) at birth (years)        PUBLISHED
# 3                   Life expectancy at age 60 (years)        PUBLISHED
# 4                   Life expectancy at age 60 (years)        PUBLISHED
# ...                                               ...              ...
# 5506  Healthy life expectancy (HALE) at birth (years)        PUBLISHED
# 5507                 Life expectancy at birth (years)        PUBLISHED
# 5508  Healthy life expectancy (HALE) at birth (years)        PUBLISHED
# 5509                 Life expectancy at birth (years)        PUBLISHED
# 5510                 Life expectancy at birth (years)        PUBLISHED
#
#      PublishStateDisplay  YearCode  YearDisplay RegionCode  \
# 0              Published      2000         2000        EMR
# 1              Published      2013         2013        EMR
# 2              Published      2013         2013        EMR
# 3              Published      2012         2012        EMR
# 4              Published      2012         2012        EMR
# ...                  ...       ...          ...        ...
# 5506           Published      2000         2000        AFR
# 5507           Published      2012         2012        AFR
# 5508           Published      2013         2013        AFR
# 5509           Published      1990         1990        AFR
# 5510           Published      2000         2000        AFR
#
#               RegionDisplay WorldBankIncomeGroupGroupCode  \
# 0     Eastern Mediterranean                         WB_LI
# 1     Eastern Mediterranean                        WB_LMI
# 2     Eastern Mediterranean                         WB_LI
# 3     Eastern Mediterranean                         WB_LI
# 4     Eastern Mediterranean                         WB_LI
# ...                     ...                           ...
# 5506                 Africa                         WB_LI
# 5507                 Africa                         WB_LI
# 5508                 Africa                         WB_LI
# 5509                 Africa                         WB_LI
# 5510                 Africa                         WB_LI
#
#      WorldBankIncomeGroupDisplay CountryCode SexCode  SexDisplay  \
# 0                     Low_income         AFG    FMLE      Female
# 1                         WB_LMI         AFG     MLE        Male
# 2                     Low_income         AFG    FMLE      Female
# 3                     Low_income         AFG    FMLE      Female
# 4                     Low_income         AFG     MLE        Male
# ...                          ...         ...     ...         ...
# 5506                  Low_income         ZWE     MLE        Male
# 5507                  Low_income         ZWE    BTSX  Both sexes
# 5508                  Low_income         ZWE    FMLE      Female
# 5509                  Low_income         ZWE     MLE        Male
# 5510                  Low_income         ZWE    BTSX  Both sexes
#
#       DisplayValue   Numeric
# 0               16  16.00000
# 1               61  60.51228
# 2               50  49.50000
# 3               17  17.00000
# 4               15  15.00000
# ...            ...       ...
# 5506            37  37.00000
# 5507            58  58.00000
# 5508            52  51.80000
# 5509            60  60.00000
# 5510            42  42.00000
#
# [5511 rows x 20 columns]

# %%
df['PublishStateCode'].unique(), df['PublishStateDisplay'].unique() #the same columns, we need one of them only
# Out:
# (array(['PUBLISHED'], dtype=object), array(['Published'], dtype=object))

# %%
df['PublishStateCode'].unique(), df['PublishStateDisplay'].unique() #we do not need it as it is the same for all.
# Out:
# (array(['PUBLISHED'], dtype=object), array(['Published'], dtype=object))

# %%
df['GhoCode'].unique(),df['GhoDisplay'].unique() #the same columns, we need one of them only
# Out:
# (array(['WHOSIS_000015', 'WHOSIS_000001', 'WHOSIS_000002'], dtype=object),
#  array(['Life expectancy at age 60 (years)',
#         'Life expectancy at birth (years)',
#         'Healthy life expectancy (HALE) at birth (years)'], dtype=object))

# %%
df['WorldBankIncomeGroupGroupCode'].unique(),df['WorldBankIncomeGroupDisplay'].unique() #we keep both
# Out:
# (array(['WB_LI', 'WB_LMI', 'WB_UMI', 'WB_HI'], dtype=object),
#  array(['Low_income', 'WB_LMI', 'Lower_middle_income',
#         'Upper_middle_income', 'High_income'], dtype=object))

# %% [markdown]
# There are some columns which are the same. So If I give encoder, it will be the same numbers. I will delete certain columns. They are duplicates.

# %%
df=df.drop(['SexCode',"CountryCode","PublishStateCode","PublishStateDisplay","GhoDisplay","YearCode","RegionDisplay","Numeric","country"],axis=1) #no need for that columns as ther are duplicated or useless.

# %%
df.head() #checking the first 5 columns
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0              0                0              0
# 1              0                0              0
# 2              0                0              0
# 3              0                0              0
# 4              0                0              0
#
#    total_litres_of_pure_alcohol        GhoCode  YearDisplay RegionCode  \
# 0                           0.0  WHOSIS_000015         2000        EMR
# 1                           0.0  WHOSIS_000001         2013        EMR
# 2                           0.0  WHOSIS_000002         2013        EMR
# 3                           0.0  WHOSIS_000015         2012        EMR
# 4                           0.0  WHOSIS_000015         2012        EMR
#
#   WorldBankIncomeGroupGroupCode WorldBankIncomeGroupDisplay SexDisplay  \
# 0                         WB_LI                  Low_income     Female
# 1                        WB_LMI                      WB_LMI       Male
# 2                         WB_LI                  Low_income     Female
# 3                         WB_LI                  Low_income     Female
# 4                         WB_LI                  Low_income       Male
#
#    DisplayValue
# 0            16
# 1            61
# 2            50
# 3            17
# 4            15

# %%
df['SexDisplay'].value_counts()
# Out:
# Female        1837
# Male          1837
# Both sexes    1837
# Name: SexDisplay, dtype: int64

# %%
df=df.rename(columns={'DisplayValue':'Age_Expectancy'}) #renaming the column for better understanding

# %%
#We use seaborn libary, scatterplot to see the location of certain data. So we are plotting subplots.
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
fig,ax=plt.subplots(2,1,figsize=(15,10))
ax[0].set_title("Spirit_servings and beer servings per person for different genders.")
sns.scatterplot(ax=ax[0],data=df,x='beer_servings',y="spirit_servings",hue="SexDisplay",s=100)
ax[1].set_title("Wine_servings and total_litres_of_pure_alcohol per person for different genders.")
sns.scatterplot(ax=ax[1],data=df,x="wine_servings",y="total_litres_of_pure_alcohol",hue="SexDisplay",s=100)
plt.show()

# %%
#count plot is used for displaying the number of certain data
plt.figure(figsize=(12,10))
sns.countplot(x='YearDisplay', hue='RegionCode', data=df)
plt.title("The account of Years according to the Region Code")
plt.show()

# %%
#we will create new column to decrease the number of age categories, so that we can see it better. 

values=[]
for i in df['Age_Expectancy'].values:
    values.append(i)
value=np.unique(values)
intervals=[0,5,15,25,40,60,80]
labels=['0 to 5', '5 to 15','15 to 25','25 to 40','40 to 60','60 to 80']
df['Age_categories']=pd.cut(df['Age_Expectancy'],intervals,labels=labels)
df
# Out:
#       beer_servings  spirit_servings  wine_servings  \
# 0                 0                0              0
# 1                 0                0              0
# 2                 0                0              0
# 3                 0                0              0
# 4                 0                0              0
# ...             ...              ...            ...
# 5506             64               18              4
# 5507             64               18              4
# 5508             64               18              4
# 5509             64               18              4
# 5510             64               18              4
#
#       total_litres_of_pure_alcohol        GhoCode  YearDisplay RegionCode  \
# 0                              0.0  WHOSIS_000015         2000        EMR
# 1                              0.0  WHOSIS_000001         2013        EMR
# 2                              0.0  WHOSIS_000002         2013        EMR
# 3                              0.0  WHOSIS_000015         2012        EMR
# 4                              0.0  WHOSIS_000015         2012        EMR
# ...                            ...            ...          ...        ...
# 5506                           4.7  WHOSIS_000002         2000        AFR
# 5507                           4.7  WHOSIS_000001         2012        AFR
# 5508                           4.7  WHOSIS_000002         2013        AFR
# 5509                           4.7  WHOSIS_000001         1990        AFR
# 5510                           4.7  WHOSIS_000001         2000        AFR
#
#      WorldBankIncomeGroupGroupCode WorldBankIncomeGroupDisplay  SexDisplay  \
# 0                            WB_LI                  Low_income      Female
# 1                           WB_LMI                      WB_LMI        Male
# 2                            WB_LI                  Low_income      Female
# 3                            WB_LI                  Low_income      Female
# 4                            WB_LI                  Low_income        Male
# ...                            ...                         ...         ...
# 5506                         WB_LI                  Low_income        Male
# 5507                         WB_LI                  Low_income  Both sexes
# 5508                         WB_LI                  Low_income      Female
# 5509                         WB_LI                  Low_income        Male
# 5510                         WB_LI                  Low_income  Both sexes
#
#       Age_Expectancy Age_categories
# 0                 16       15 to 25
# 1                 61       60 to 80
# 2                 50       40 to 60
# 3                 17       15 to 25
# 4                 15        5 to 15
# ...              ...            ...
# 5506              37       25 to 40
# 5507              58       40 to 60
# 5508              52       40 to 60
# 5509              60       40 to 60
# 5510              42       40 to 60
#
# [5511 rows x 12 columns]

# %%
#we use histplot as it describes the relation between 2 different columns.
fig,ax=plt.subplots(3,1,figsize=(9,15))
sns.histplot(ax=ax[1],data=df,x='SexDisplay',hue='Age_categories')
sns.histplot(ax=ax[0],data=df,x='WorldBankIncomeGroupDisplay',hue='Age_categories')
sns.histplot(ax=ax[2],data=df,x='WorldBankIncomeGroupGroupCode',hue='Age_categories')
plt.show()

# %%
df
# Out:
#       beer_servings  spirit_servings  wine_servings  \
# 0                 0                0              0
# 1                 0                0              0
# 2                 0                0              0
# 3                 0                0              0
# 4                 0                0              0
# ...             ...              ...            ...
# 5506             64               18              4
# 5507             64               18              4
# 5508             64               18              4
# 5509             64               18              4
# 5510             64               18              4
#
#       total_litres_of_pure_alcohol        GhoCode  YearDisplay RegionCode  \
# 0                              0.0  WHOSIS_000015         2000        EMR
# 1                              0.0  WHOSIS_000001         2013        EMR
# 2                              0.0  WHOSIS_000002         2013        EMR
# 3                              0.0  WHOSIS_000015         2012        EMR
# 4                              0.0  WHOSIS_000015         2012        EMR
# ...                            ...            ...          ...        ...
# 5506                           4.7  WHOSIS_000002         2000        AFR
# 5507                           4.7  WHOSIS_000001         2012        AFR
# 5508                           4.7  WHOSIS_000002         2013        AFR
# 5509                           4.7  WHOSIS_000001         1990        AFR
# 5510                           4.7  WHOSIS_000001         2000        AFR
#
#      WorldBankIncomeGroupGroupCode WorldBankIncomeGroupDisplay  SexDisplay  \
# 0                            WB_LI                  Low_income      Female
# 1                           WB_LMI                      WB_LMI        Male
# 2                            WB_LI                  Low_income      Female
# 3                            WB_LI                  Low_income      Female
# 4                            WB_LI                  Low_income        Male
# ...                            ...                         ...         ...
# 5506                         WB_LI                  Low_income        Male
# 5507                         WB_LI                  Low_income  Both sexes
# 5508                         WB_LI                  Low_income      Female
# 5509                         WB_LI                  Low_income        Male
# 5510                         WB_LI                  Low_income  Both sexes
#
#       Age_Expectancy Age_categories
# 0                 16       15 to 25
# 1                 61       60 to 80
# 2                 50       40 to 60
# 3                 17       15 to 25
# 4                 15        5 to 15
# ...              ...            ...
# 5506              37       25 to 40
# 5507              58       40 to 60
# 5508              52       40 to 60
# 5509              60       40 to 60
# 5510              42       40 to 60
#
# [5511 rows x 12 columns]

# %%
for i in ['GhoCode',"RegionCode","WorldBankIncomeGroupGroupCode","WorldBankIncomeGroupDisplay","SexDisplay"]:
  print(df[i].value_counts())
# Out:
# WHOSIS_000015    2004
# WHOSIS_000001    2004
# WHOSIS_000002    1503
# Name: GhoCode, dtype: int64
# EUR     1617
# AFR     1353
# AMR      891
# WPR      726
# EMR      627
# SEAR     297
# Name: RegionCode, dtype: int64
# WB_LMI    2217
# WB_HI     1215
# WB_UMI    1053
# WB_LI     1026
# Name: WorldBankIncomeGroupGroupCode, dtype: int64
# Lower_middle_income    1215
# High_income            1215
# Upper_middle_income    1053
# Low_income             1026
# WB_LMI                 1002
# Name: WorldBankIncomeGroupDisplay, dtype: int64
# Female        1837
# Male          1837
# Both sexes    1837
# Name: SexDisplay, dtype: int64

# %%
df.dtypes
# Out:
# beer_servings                       int64
# spirit_servings                     int64
# wine_servings                       int64
# total_litres_of_pure_alcohol      float64
# GhoCode                            object
# YearDisplay                         int64
# RegionCode                         object
# WorldBankIncomeGroupGroupCode      object
# WorldBankIncomeGroupDisplay        object
# SexDisplay                         object
# Age_Expectancy                      int64
# Age_categories                   category
# dtype: object

# %%
#we need to encode the text data so the algorithm can understand.
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
objects=['GhoCode',"RegionCode","WorldBankIncomeGroupGroupCode","WorldBankIncomeGroupDisplay","SexDisplay"]
for i in objects:
  df[i]=lb.fit_transform(df[i])

# %%
df
# Out:
#       beer_servings  spirit_servings  wine_servings  \
# 0                 0                0              0
# 1                 0                0              0
# 2                 0                0              0
# 3                 0                0              0
# 4                 0                0              0
# ...             ...              ...            ...
# 5506             64               18              4
# 5507             64               18              4
# 5508             64               18              4
# 5509             64               18              4
# 5510             64               18              4
#
#       total_litres_of_pure_alcohol  GhoCode  YearDisplay  RegionCode  \
# 0                              0.0        2         2000           2
# 1                              0.0        0         2013           2
# 2                              0.0        1         2013           2
# 3                              0.0        2         2012           2
# 4                              0.0        2         2012           2
# ...                            ...      ...          ...         ...
# 5506                           4.7        1         2000           0
# 5507                           4.7        0         2012           0
# 5508                           4.7        1         2013           0
# 5509                           4.7        0         1990           0
# 5510                           4.7        0         2000           0
#
#       WorldBankIncomeGroupGroupCode  WorldBankIncomeGroupDisplay  SexDisplay  \
# 0                                 1                            1           1
# 1                                 2                            4           2
# 2                                 1                            1           1
# 3                                 1                            1           1
# 4                                 1                            1           2
# ...                             ...                          ...         ...
# 5506                              1                            1           2
# 5507                              1                            1           0
# 5508                              1                            1           1
# 5509                              1                            1           2
# 5510                              1                            1           0
#
#       Age_Expectancy Age_categories
# 0                 16       15 to 25
# 1                 61       60 to 80
# 2                 50       40 to 60
# 3                 17       15 to 25
# 4                 15        5 to 15
# ...              ...            ...
# 5506              37       25 to 40
# 5507              58       40 to 60
# 5508              52       40 to 60
# 5509              60       40 to 60
# 5510              42       40 to 60
#
# [5511 rows x 12 columns]

# %%
for i in ['GhoCode',"RegionCode","WorldBankIncomeGroupGroupCode","WorldBankIncomeGroupDisplay","SexDisplay"]:
  print(df[i].value_counts())
# Out:
# 2    2004
# 0    2004
# 1    1503
# Name: GhoCode, dtype: int64
# 3    1617
# 0    1353
# 1     891
# 5     726
# 2     627
# 4     297
# Name: RegionCode, dtype: int64
# 2    2217
# 0    1215
# 3    1053
# 1    1026
# Name: WorldBankIncomeGroupGroupCode, dtype: int64
# 2    1215
# 0    1215
# 3    1053
# 1    1026
# 4    1002
# Name: WorldBankIncomeGroupDisplay, dtype: int64
# 1    1837
# 2    1837
# 0    1837
# Name: SexDisplay, dtype: int64

# %%
#a pairplot shows the linerity between the columns
sns.pairplot(df) #let's find the linerity between columns.
plt.show()

# %%
#we do not need that column anymore
df=df.drop("Age_categories",axis=1)

# %%
#calculation the correlation of other columns to the target column.
df.corrwith(df['Age_Expectancy']).abs().sort_values(ascending=False)
# Out:
# Age_Expectancy                   1.000000
# GhoCode                          0.889930
# YearDisplay                      0.140998
# wine_servings                    0.137953
# RegionCode                       0.135728
# beer_servings                    0.123758
# total_litres_of_pure_alcohol     0.114368
# spirit_servings                  0.099091
# WorldBankIncomeGroupDisplay      0.067911
# WorldBankIncomeGroupGroupCode    0.051473
# SexDisplay                       0.031045
# dtype: float64

# %%
#correlation is really important, so we plot it with heatmap and see better.
corrm=df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(corrm, cmap="coolwarm", annot=True)
plt.plot()
# Out:
# []

# %%
#we identify what is input and what is the supervised output
X=df.drop('Age_Expectancy',axis=1)
Y=df['Age_Expectancy'].copy()

# %%
#Mutual info is also needed to see the correlation, it is an alternative of df.corr()
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X, Y)
mutual_info
# Out:
# array([0.29350324, 0.28329847, 0.25369428, 0.30931982, 0.76584066,
#        0.05435493, 0.30775418, 0.26290601, 0.32056014, 0.0662742 ])

# %%
mutual_info = pd.Series(mutual_info) 
mutual_info.index = X.columns
milist=mutual_info.sort_values(ascending=False)
milist
# Out:
# GhoCode                          0.765841
# WorldBankIncomeGroupDisplay      0.320560
# total_litres_of_pure_alcohol     0.309320
# RegionCode                       0.307754
# beer_servings                    0.293503
# spirit_servings                  0.283298
# WorldBankIncomeGroupGroupCode    0.262906
# wine_servings                    0.253694
# SexDisplay                       0.066274
# YearDisplay                      0.054355
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8)) #plotting mutual_info

# %%
#decreasing the values, giving a standart scale to them
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)
X
# Out:
# array([[-1.03615689, -0.92523874, -0.62356526, ..., -0.54546113,
#         -0.65902496,  0.        ],
#        [-1.03615689, -0.92523874, -0.62356526, ...,  0.42173201,
#          1.47236387,  1.22474487],
#        [-1.03615689, -0.92523874, -0.62356526, ..., -0.54546113,
#         -0.65902496,  0.        ],
#        ...,
#        [-0.41556598, -0.72029676, -0.57532093, ..., -0.54546113,
#         -0.65902496,  0.        ],
#        [-0.41556598, -0.72029676, -0.57532093, ..., -0.54546113,
#         -0.65902496,  1.22474487],
#        [-0.41556598, -0.72029676, -0.57532093, ..., -0.54546113,
#         -0.65902496, -1.22474487]])

# %%
#splitting the data for testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
#calling linear regression
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#calling logistic regression
from sklearn.linear_model import LogisticRegression
LgR_model=LogisticRegression(max_iter=2000)
LgR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
#finding the best k value for max_leaf_nodes and max_depth in Tree algorithm
from sklearn import metrics,tree
f1 = []
for k in range(2,25):
    dt = tree.DecisionTreeClassifier(max_leaf_nodes=k)
    dt.fit(x_train, y_train)
    y_predict = dt.predict(x_test)
    f1.append(metrics.mean_squared_error(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(2,25),f1)
plt.xticks(range(2,25))
plt.grid()
plt.show()

f1 = []
for k in range(1,25):
    dt = tree.DecisionTreeClassifier(max_depth=k)
    dt.fit(x_train, y_train)
    y_predict = dt.predict(x_test)
    f1.append(metrics.mean_squared_error(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(1,25),f1)
plt.xticks(range(1,25))
plt.grid()
plt.show()

# %%
#applying Decision Tree Classifier 
from sklearn import tree
DT_model = tree.DecisionTreeClassifier(max_leaf_nodes=24,max_depth=24)
DT_model = DT_model.fit(x_train, y_train)

# %%
#finding the number of neighbours for KNeighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
f1 = []
for k in range(1,25):
    knn_model =KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(x_train, y_train)
    y_predict = knn_model.predict(x_test)
    f1.append(metrics.mean_absolute_error(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(1,25),f1)
plt.xticks(range(1,25))
plt.grid()
plt.show()

# %%
#applying KNeighbors Classifier
knn_model =KNeighborsClassifier(n_neighbors=21)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
#a function to evaluate out model with mean squared error and absolute error.
def evaluation(model):
  score = model.score(x_test, y_test)
  y_predicted=model.predict(x_test)
  mse=metrics.mean_squared_error(y_test,y_predicted)
  mae=metrics.mean_absolute_error(y_test,y_predicted)
  print("Mean Squared error: ", mse)
  print("Mean Absolute error: ", mae)

# %%
evaluation(knn_model) #applying the function
# Out:
# Mean Squared error:  97.31368993653672
# Mean Absolute error:  5.29374433363554

# %%
evaluation(LR_model)  #applying the function
# Out:
# Mean Squared error:  75.20225580662051
# Mean Absolute error:  6.878098621842378

# %%
evaluation(LgR_model)  #applying the function
# Out:
# Mean Squared error:  35.45240253853128
# Mean Absolute error:  4.210335448776065

# %%
evaluation(DT_model)  #applying the function
# Out:
# Mean Squared error:  29.85494106980961
# Mean Absolute error:  3.755213055303717

# %%
#let's make a pipeline.
from sklearn.pipeline import Pipeline
from joblib import dump,load

pipeline=Pipeline([
    ("Scaler",StandardScaler()),
    ("classifier",DT_model)

])

# %%
dump(pipeline, 'pipeline.joblib')
# Out:
# ['pipeline.joblib']
